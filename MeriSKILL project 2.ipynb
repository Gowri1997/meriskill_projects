# %% [markdown]
# ## Diabetes Patients
#
# ### Author: Gowri S
#
# In this we will be using the python code to predict the patient diabetic or not  by taking many factors like age,blood pressure etc. as input using different classifier machine learning technique .I will be describing the process in different steps.

# %% [markdown]
# ## Importing necessary libraries
#
# Here we will be importing the necessary libraries for data analysis and data cleaning and for importing the dataset in dataframe format.This includes the padas, numpy and visualization libraries like matplotlib and seaborn.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Importing the data

# %%
df=pd.read_csv(r'C:\Users\hp\Downloads\Project 2 MeriSKILL\diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# Information about dataset attributes -
#
# Pregnancies: To express the Number of pregnancies
#
# Glucose: To express the Glucose level in blood
#
# BloodPressure: To express the Blood pressure measurement
#
# SkinThickness: To express the thickness of the skin
#
# Insulin: To express the Insulin level in blood
#
# BMI: To express the Body mass index
#
# DiabetesPedigreeFunction: To express the Diabetes percentage
#
# Age: To express the age
#
# Outcome: To express the final result 1 is Yes and 0 is No
#
# Pregnancies
# To express the Number of pregnancies
#
# Glucose

# %% [markdown]
# ### 5. Data analysis

# %% [markdown]
# This is the next basic nature of the data.We will be looking the feature variables,target variables.Further we will be looking data set in details for the shape,data types ,presence of null values and distribution of data points using describe option.It will give mean,standard deviation ,percentile distribution,total count of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.Pregnancies.unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14],
#       dtype=int64)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ## Data visualisation

# %%
pd.DataFrame(df[['Pregnancies']].value_counts()).sort_values(by='Pregnancies')
# Out:
#                0
# Pregnancies
# 0            111
# 1            135
# 2            103
# 3             75
# 4             68
# 5             57
# 6             50
# 7             45
# 8             38
# 9             28
# 10            24
# 11            11
# 12             9
# 13            10
# 14             2
# 15             1
# 17             1

# %%
plt.figure(figsize=(8,5))
sn.distplot(df['Pregnancies'], bins = 30,color='magenta')
plt.title('Distribution of pregnencies')
# Out:
# Text(0.5, 1.0, 'Distribution of pregnencies')

# %%
df['BloodPressure'].unique()
# Out:
# array([ 72,  66,  64,  40,  74,  50,   0,  70,  96,  92,  80,  60,  84,
#         30,  88,  90,  94,  76,  82,  75,  58,  78,  68, 110,  56,  62,
#         85,  86,  48,  44,  65, 108,  55, 122,  54,  52,  98, 104,  95,
#         46, 102, 100,  61,  24,  38, 106, 114], dtype=int64)

# %%
plt.figure(figsize=(8,5))
sn.distplot(df['BloodPressure'], bins = 30,color='green')
plt.title('Distribution of BloodPressure')
# Out:
# Text(0.5, 1.0, 'Distribution of BloodPressure')

# %%
plt.figure(figsize=(6,5))
g = sn.catplot(data=df, x="Outcome", y="BloodPressure", kind="violin", inner=None)
sn.swarmplot(data=df, x="Outcome", y="BloodPressure", color="k", size=3, ax=g.ax)
# Out:
# <Axes: xlabel='Outcome', ylabel='BloodPressure'>

# %% [markdown]
# 0 blood pressure is not an accountable data.so we are replacing 0 with mean value

# %%
sn.displot(df, x="Age")

# %%
plt.figure(figsize=(6,5))
sn.catplot(data=df, x="Outcome", y="Age", kind="box")

# %%
plt.figure(figsize=(6,5))
sn.displot(df,x='BMI',color='black',kind="kde")
plt.title('Distribution of BMI')
# Out:
# Text(0.5, 1.0, 'Distribution of BMI')

# %%
bins = pd.IntervalIndex.from_tuples([(0, 18.5), (18.5, 25), (25, 30), (30, 80)], closed='left')
lab=['underweight','Healthyweight','overweight','obese']
df['bmi_lab'] = np.array(lab)[pd.cut(df["BMI"], bins = bins).cat.codes]
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome        bmi_lab
# 0                     0.627   50        1          obese
# 1                     0.351   31        0     overweight
# 2                     0.672   32        1  Healthyweight
# 3                     0.167   21        0     overweight
# 4                     2.288   33        1          obese

# %%
df[['bmi_lab']].value_counts()
# Out:
# bmi_lab
# obese            472
# overweight       179
# Healthyweight    102
# underweight       15
# dtype: int64

# %%
sn.catplot(data=df, x="bmi_lab", kind="count",hue="Outcome", palette="ch:.25")

# %%
bins = pd.IntervalIndex.from_tuples([(0, 10), (10, 25), (25, 50), (50, 100)], closed='left')
category=['child','junior','adult','senior']
df['Age_group'] = np.array(category)[pd.cut(df["Age"], bins = bins).cat.codes]
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome        bmi_lab Age_group
# 0                     0.627   50        1          obese    senior
# 1                     0.351   31        0     overweight     adult
# 2                     0.672   32        1  Healthyweight     adult
# 3                     0.167   21        0     overweight    junior
# 4                     2.288   33        1          obese     adult

# %%
df.Age_group.value_counts()
# Out:
# adult     460
# junior    219
# senior     89
# Name: Age_group, dtype: int64

# %%
sn.catplot(data=df, x="Outcome", kind="count",hue="Age_group",palette="ch:.25")

# %%
plt.figure(figsize=(6,5))
sn.boxplot(x='Outcome',y='DiabetesPedigreeFunction',data=df)
# Out:
# <Axes: xlabel='Outcome', ylabel='DiabetesPedigreeFunction'>

# %%
plt.figure(figsize=(6,5))
sn.boxplot(x='Outcome',y='Glucose',data=df)
# Out:
# <Axes: xlabel='Outcome', ylabel='Glucose'>

# %%
df.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
plt.figure(figsize=(6,5))
sn.displot(df, x="Outcome", discrete=True,shrink=.8)

# %% [markdown]
# ## Data Preprocessing¶

# %% [markdown]
# #### Feature engineering

# %%
plt.figure(figsize=(10,7))
sn.heatmap(df.corr(),annot=True,fmt=".2%",cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# #### Outlier Removal

# %%
avg = df['BloodPressure'].mean()
df['BloodPressure'] = df['BloodPressure'].apply(lambda v: avg if v==0 else v)

# %%
plt.figure(figsize=(8,5))
sn.distplot(df['BloodPressure'], bins = 30,color='orange')
plt.title('Distribution of BloodPressure')
# Out:
# Text(0.5, 1.0, 'Distribution of BloodPressure')

# %%
bmi_avg = df['BMI'].mean()
df['BMI'] = df['BMI'].apply(lambda v: bmi_avg if v==0 else v)

# %%
plt.figure(figsize=(8,5))
sn.displot(df,x='BMI',color='black',kind="kde")
plt.title('Distribution of BMI')
# Out:
# Text(0.5, 1.0, 'Distribution of BMI')

# %% [markdown]
# As seen earlier there are amount which varies largely from rest of amount.It may not me outlier in real case but for better modelling we need to remove it.In above variable i replaced outlier value with  mean.
# Now lets use z-score technique to see outlier in other feature variables.

# %%
df['z_score_bp']=(df.BloodPressure-df.BloodPressure.mean())/df.BloodPressure.std()
df['z_score_Glucose']=(df.Glucose-df.Glucose.mean())/df.Glucose.std()

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148           72.0             35        0  33.6
# 1            1       85           66.0             29        0  26.6
# 2            8      183           64.0              0        0  23.3
# 3            1       89           66.0             23       94  28.1
# 4            0      137           40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome        bmi_lab Age_group  \
# 0                     0.627   50        1          obese    senior
# 1                     0.351   31        0     overweight     adult
# 2                     0.672   32        1  Healthyweight     adult
# 3                     0.167   21        0     overweight    junior
# 4                     2.288   33        1          obese     adult
#
#    z_score_bp  z_score_Glucose
# 0   -0.021031         0.847771
# 1   -0.516246        -1.122665
# 2   -0.681318         1.942458
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      72.254807      20.536458   79.799479
# std       3.369578   31.972618      12.115932      15.952218  115.244002
# min       0.000000    0.000000      24.000000       0.000000    0.000000
# 25%       1.000000   99.000000      64.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome  \
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# ...

# %%
df.drop(columns=['bmi_lab','Age_group','z_score_bp','z_score_Glucose'],inplace=True)
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148           72.0             35        0  33.6
# 1            1       85           66.0             29        0  26.6
# 2            8      183           64.0              0        0  23.3
# 3            1       89           66.0             23       94  28.1
# 4            0      137           40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## Split Data

# %%
X=df.drop(columns='Outcome')
Y=df['Outcome']

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148           72.0             35        0  33.6
# 1            1       85           66.0             29        0  26.6
# 2            8      183           64.0              0        0  23.3
# 3            1       89           66.0             23       94  28.1
# 4            0      137           40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
Y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
X.shape,Y.shape
# Out:
# ((768, 8), (768,))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((614, 8), (154, 8), (614,), (154,))

# %% [markdown]
# ## Model building

# %% [markdown]
# ## Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
m_1=LogisticRegression()

# %%
m_1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predicted_l=m_1.predict(x_test)

# %%
m_1.score(x_test,y_test)
# Out:
# 0.7207792207792207

# %% [markdown]
# Evaluate the models performance using matrics like accuracy,confution matric and classification report

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
accuracy_l=accuracy_score(y_test,y_predicted_l)
accuracy_l
# Out:
# 0.7207792207792207

# %%
cm_l=confusion_matrix(y_test,y_predicted_l)
print(cm_l)
# Out:
# [[79 12]
#  [31 32]]

# %%
class_report_l=classification_report(y_test,y_predicted_l)
print(class_report_l)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.87      0.79        91
#            1       0.73      0.51      0.60        63
#
#     accuracy                           0.72       154
#    macro avg       0.72      0.69      0.69       154
# weighted avg       0.72      0.72      0.71       154

# %% [markdown]
# ## Gaussian Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
m_NB=GaussianNB()

# %%
m_NB.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_predicted_NB=m_NB.predict(x_test)

# %%
m_NB.score(x_test,y_test)
# Out:
# 0.7077922077922078

# %% [markdown]
# Evaluate the models performance using matrics like accuracy,confution matric and classification report

# %%
accuracy_NB=accuracy_score(y_test,y_predicted_NB)
accuracy_NB
# Out:
# 0.7077922077922078

# %%
cm_NB=confusion_matrix(y_test,y_predicted_NB)
print(cm_NB)
# Out:
# [[75 16]
#  [29 34]]

# %%
class_report_NB=classification_report(y_test,y_predicted_NB)
print(class_report_NB)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.82      0.77        91
#            1       0.68      0.54      0.60        63
#
#     accuracy                           0.71       154
#    macro avg       0.70      0.68      0.69       154
# weighted avg       0.70      0.71      0.70       154

# %% [markdown]
# ## Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
m_d=DecisionTreeClassifier()

# %%
m_d.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predicted_d=m_d.predict(x_test)

# %%
m_d.score(x_test,y_test)
# Out:
# 0.7142857142857143

# %% [markdown]
# Evaluate the models performance using matrics like accuracy,confution matric and classification report

# %%
accuracy_d=accuracy_score(y_test,y_predicted_d)
accuracy_d
# Out:
# 0.7142857142857143

# %%
cm_d=confusion_matrix(y_test,y_predicted_d)
print(cm_d)
# Out:
# [[74 17]
#  [27 36]]

# %%
class_report_d=classification_report(y_test,y_predicted_d)
print(class_report_d)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77        91
#            1       0.68      0.57      0.62        63
#
#     accuracy                           0.71       154
#    macro avg       0.71      0.69      0.70       154
# weighted avg       0.71      0.71      0.71       154

# %% [markdown]
# ## Randonforest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
m_forest=RandomForestClassifier(n_estimators=10)

# %%
m_forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
y_predicted_r=m_forest.predict(x_test)

# %%
m_forest.score(x_test,y_test)
# Out:
# 0.7272727272727273

# %% [markdown]
# Evaluate the models performance using matrics like accuracy,confution matric and classification report

# %%
accuracy_r=accuracy_score(y_test,y_predicted_r)
accuracy_r
# Out:
# 0.7272727272727273

# %%
cm_r=confusion_matrix(y_test,y_predicted_r)
print(cm_r)
# Out:
# [[82  9]
#  [33 30]]

# %%
class_report_r=classification_report(y_test,y_predicted_r)
print(class_report_r)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.90      0.80        91
#            1       0.77      0.48      0.59        63
#
#     accuracy                           0.73       154
#    macro avg       0.74      0.69      0.69       154
# weighted avg       0.74      0.73      0.71       154
